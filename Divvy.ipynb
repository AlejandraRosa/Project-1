# %%
# Dependencies
import pandas as pd
#import glob

# %%
# File to Load
q1_2018_csv = "Resources/Divvy_Trips_2018_Q1.csv"
q2_2018_csv = "Resources/Divvy_Trips_2018_Q2.csv"
q3_2018_csv = "Resources/Divvy_Trips_2018_Q3.csv"
q4_2018_csv = "Resources/Divvy_Trips_2018_Q4.csv"

# Read School and Student Data File and store into Pandas Data Frames
q1_data = pd.read_csv(q1_2018_csv)
q2_data = pd.read_csv(q2_2018_csv)
q3_data = pd.read_csv(q3_2018_csv)
q4_data = pd.read_csv(q4_2018_csv)

# %%
q1_data.head()
# Out:
#     trip_id     start_time       end_time  bikeid tripduration  \
# 0  17536702  1/1/2018 0:12  1/1/2018 0:17    3304          323
# 1  17536703  1/1/2018 0:41  1/1/2018 0:47    5367          377
# 2  17536704  1/1/2018 0:44  1/1/2018 1:33    4599     2,904.00
# 3  17536705  1/1/2018 0:53  1/1/2018 1:05    2302          747
# 4  17536706  1/1/2018 0:53  1/1/2018 0:56    3696          183
#
#    from_station_id            from_station_name  to_station_id  \
# 0               69       Damen Ave & Pierce Ave            159
# 1              253  Winthrop Ave & Lawrence Ave            325
# 2               98   LaSalle St & Washington St            509
# 3              125         Rush St & Hubbard St            364
# 4              129    Blue Island Ave & 18th St            205
#
#                   to_station_name    usertype gender  birthyear
# 0       Claremont Ave & Hirsch St  Subscriber   Male     1988.0
# 1  Clark St & Winnemac Ave (Temp)  Subscriber   Male     1984.0
# ...

# %%
q2_data.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  18000527  2018-04-01 00:04:44  2018-04-01 00:13:03    3819        499.0
# 1  18000528  2018-04-01 00:06:42  2018-04-01 00:27:07    5000      1,225.0
# 2  18000529  2018-04-01 00:07:19  2018-04-01 00:23:19    5165        960.0
# 3  18000530  2018-04-01 00:07:33  2018-04-01 00:14:47    3851        434.0
# 4  18000531  2018-04-01 00:10:23  2018-04-01 00:22:12    5065        709.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0               22              May St & Taylor St            171
# 1              157  Lake Shore Dr & Wellington Ave            190
# 2              106           State St & Pearson St            106
# 3              241             Morgan St & Polk St            171
# 4              228         Damen Ave & Melrose Ave            219
#
#                   to_station_name    usertype gender  birthyear
# ...

# %%
q3_data.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  19244622  2018-07-01 00:00:03  2018-07-01 23:56:11    5429     86,168.0
# 1  19244623  2018-07-01 00:00:13  2018-07-01 00:06:39      93        386.0
# 2  19244624  2018-07-01 00:00:15  2018-07-01 00:23:26    2461      1,391.0
# 3  19244625  2018-07-01 00:00:25  2018-07-01 00:23:31    2991      1,386.0
# 4  19244626  2018-07-01 00:00:27  2018-07-01 00:11:23    2851        656.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0              140     Dearborn Pkwy & Delaware Pl            106
# 1              153  Southport Ave & Wellington Ave            250
# 2               76       Lake Shore Dr & Monroe St            301
# 3               76       Lake Shore Dr & Monroe St            301
# 4               60           Dayton St & North Ave            166
#
#                 to_station_name    usertype  gender  birthyear
# ...

# %%
q4_data.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  20983530  2018-10-01 00:01:17  2018-10-01 00:29:35    4551      1,698.0
# 1  20983531  2018-10-01 00:03:59  2018-10-01 00:10:55     847        416.0
# 2  20983532  2018-10-01 00:05:14  2018-10-01 00:14:08    6188        534.0
# 3  20983533  2018-10-01 00:05:48  2018-10-01 00:18:46    6372        778.0
# 4  20983534  2018-10-01 00:07:29  2018-10-01 00:25:51    1927      1,102.0
#
#    from_station_id           from_station_name  to_station_id  \
# 0               85       Michigan Ave & Oak St            166
# 1               13  Wilton Ave & Diversey Pkwy            144
# 2               59   Wabash Ave & Roosevelt Rd            197
# 3              328         Ellis Ave & 58th St            419
# 4               93   Sheffield Ave & Willow St            159
#
#                 to_station_name    usertype  gender  birthyear
# 0  Ashland Ave & Wrightwood Ave  Subscriber    Male     1992.0
# ...

# %%
#loop through all 4 divvy files and combine into one frame
    #https://gist.github.com/arsham/1c3a2d0768560d6d8729b9af0af2bbc1#file-concatenate-multiple-csv-files-in-panda-py

divvy_data = []
for f in glob.glob("Resources/Divvy_Trips_2018_*.csv"):
   divvy_data.append(pd.read_csv(f))

divvy_combined = pd.concat(fds)

# %%
divvy_combined
# Out:
#          trip_id           start_time             end_time  bikeid  \
# 0       17536702        1/1/2018 0:12        1/1/2018 0:17    3304
# 1       17536703        1/1/2018 0:41        1/1/2018 0:47    5367
# 2       17536704        1/1/2018 0:44        1/1/2018 1:33    4599
# 3       17536705        1/1/2018 0:53        1/1/2018 1:05    2302
# 4       17536706        1/1/2018 0:53        1/1/2018 0:56    3696
# ...          ...                  ...                  ...     ...
# 642681  21742438  2018-12-31 23:45:17  2018-12-31 23:50:05    2931
# 642682  21742439  2018-12-31 23:48:48  2018-12-31 23:57:22    4386
# 642683  21742440  2018-12-31 23:50:09  2018-12-31 23:57:16    4927
# 642684  21742441  2018-12-31 23:55:04  2018-12-31 23:58:24    1350
# 642685  21742442  2018-12-31 23:59:18  2019-01-01 00:20:43    2006
#
#        tripduration  from_station_id               from_station_name  \
# 0               323               69          Damen Ave & Pierce Ave
# ...

# %%
divvy_df = pd.DataFrame(divvy_combined.groupby(["from_station_name"])["bikeid"].count().reset_index())

# %%
divvy_df
# Out:
#                 from_station_name  bikeid
# 0             2112 W Peterson Ave     456
# 1                   63rd St Beach     956
# 2               900 W Harrison St    6187
# 3      Aberdeen St & Jackson Blvd   12056
# 4         Aberdeen St & Monroe St    9875
# ..                            ...     ...
# 617           Wood St & Taylor St    5987
# 618        Woodlawn Ave & 55th St    3488
# 619        Woodlawn Ave & 75th St      30
# 620  Woodlawn Ave & Lake Park Ave    1010
# 621          Yates Blvd & 75th St     103
#
# [622 rows x 2 columns]
